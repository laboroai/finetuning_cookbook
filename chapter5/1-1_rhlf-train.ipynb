# %% [markdown]
# # 文書生成AIのファインチューニング・レシピ
# 本Notebookでは、MARC-jaというAmazonのレビューデータセットに対する分類モデルを報酬モデルとして用いたRLHFにより事前学習済みモデルをファインチューニングするコードを記載します。

# %% [markdown]
# ## 事前準備
# 利用するライブラリのインストールやモデルのロード、データセットの準備を行います。

# %% [markdown]
# ### (1) Hugging Face HubとWeights & Biasesのアカウント作成
# それぞれのサービスのウェブサイトでアカウントを作成します。

# %% [markdown]
# ### (2) ライブラリのインストール
# 利用するライブラリをインストールします。

# %%
# %pip install transformers==4.35.2
# %pip install trl[peft]==0.7.10
# %pip install wandb==0.16.2
# %pip install sentencepiece==0.1.99
# %pip install accelerate==0.26.1
# %pip install bitsandbytes==0.42.0
# Out:
# Collecting transformers==4.35.2
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.35.2)
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (2024.7.4)
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 95.9 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 80.4 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# Successfully installed tokenizers-0.15.2 transformers-4.35.2
# Collecting trl==0.7.10 (from trl[peft]==0.7.10)
#   Downloading trl-0.7.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.10->trl[peft]==0.7.10) (2.4.0+cu121)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.10->trl[peft]==0.7.10) (4.35.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.10->trl[peft]==0.7.10) (1.26.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from trl==0.7.10->trl[peft]==0.7.10) (0.32.1)
# Collecting datasets (from trl==0.7.10->trl[peft]==0.7.10)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting tyro>=0.5.11 (from trl==0.7.10->trl[peft]==0.7.10)
#   Downloading tyro-0.8.10-py3-none-any.whl.metadata (8.4 kB)
# Collecting peft>=0.4.0 (from trl[peft]==0.7.10)
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft>=0.4.0->trl[peft]==0.7.10) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft>=0.4.0->trl[peft]==0.7.10) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft>=0.4.0->trl[peft]==0.7.10) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft>=0.4.0->trl[peft]==0.7.10) (4.66.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft>=0.4.0->trl[peft]==0.7.10) (0.4.4)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft>=0.4.0->trl[peft]==0.7.10) (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (2024.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (0.15.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.10->trl[peft]==0.7.10) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.10->trl[peft]==0.7.10) (13.8.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl==0.7.10->trl[peft]==0.7.10)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting pyarrow>=15.0.0 (from datasets->trl==0.7.10->trl[peft]==0.7.10)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->trl==0.7.10->trl[peft]==0.7.10)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.10->trl[peft]==0.7.10) (2.1.4)
# Collecting xxhash (from datasets->trl==0.7.10->trl[peft]==0.7.10)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->trl==0.7.10->trl[peft]==0.7.10)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.7.10->trl[peft]==0.7.10) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.7.10->trl[peft]==0.7.10) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->trl==0.7.10->trl[peft]==0.7.10) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.10->trl[peft]==0.7.10) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.10->trl[peft]==0.7.10) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.7.10->trl[peft]==0.7.10) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.7.10->trl[peft]==0.7.10) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.7.10->trl[peft]==0.7.10) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl==0.7.10->trl[peft]==0.7.10) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.10->trl[peft]==0.7.10) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.7.10->trl[peft]==0.7.10) (1.16.0)
# Downloading trl-0.7.10-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 14.2 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 28.7 MB/s eta 0:00:00
# Downloading tyro-0.8.10-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 11.9 MB/s eta 0:00:00
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 41.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.9 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 51.2 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, shtab, pyarrow, dill, multiprocess, tyro, datasets, trl, peft
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.21.0 dill-0.3.8 multiprocess-0.70.16 peft-0.12.0 pyarrow-17.0.0 shtab-1.7.1 trl-0.7.10 tyro-0.8.10 xxhash-3.5.0
# Collecting wandb==0.16.2
#   Downloading wandb-0.16.2-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb==0.16.2)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.16.2)
#   Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.16.2)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (6.0.2)
# Collecting setproctitle (from wandb==0.16.2)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (71.0.4)
# Collecting appdirs>=1.4.3 (from wandb==0.16.2)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.2) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.2)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.2) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.2) (2024.7.4)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.2)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.16.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 22.1 MB/s eta 0:00:00
# Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 29.3 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: appdirs, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.43 appdirs-1.4.4 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-2.13.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.2
# Requirement already satisfied: sentencepiece==0.1.99 in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Collecting accelerate==0.26.1
#   Downloading accelerate-0.26.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (2.4.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (0.23.5)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1) (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (2024.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.26.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.26.1) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.26.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.26.1) (1.3.0)
# Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 20.8 MB/s eta 0:00:00
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.32.1
#     Uninstalling accelerate-0.32.1:
#       Successfully uninstalled accelerate-0.32.1
# Successfully installed accelerate-0.26.1
# Collecting bitsandbytes==0.42.0
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.42.0) (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy->bitsandbytes==0.42.0) (1.26.4)
# Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 22.6 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.42.0

# %% [markdown]
# ### (3) Weights & Biases及びHugging Face Hubへのログイン
# 学習時のログを記録するWeights & Biases、及び訓練後のモデルの保存先であるHuggingface Hubにログインします。

# %%
import wandb
wandb.init()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.17.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/content/wandb/run-20240830_093645-7nymfq16</code>
# Syncing run <strong><a href='https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized/runs/7nymfq16' target="_blank">dainty-sun-34</a></strong> to <a href='https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized' target="_blank">https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized</a>
#  View run at <a href='https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized/runs/7nymfq16' target="_blank">https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized/runs/7nymfq16</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized/runs/7nymfq16?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ライブラリをインポートします。

# %%
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset
from peft import LoraConfig
from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %% [markdown]
# ### (4) データセットの準備
# モデル名とデータセット名を定義します。ファインチューニング後のモデルは`save_model_name`という名前でHugging Face Hub上に保存されます。

# %%
rm_name = 'Mizuiro-sakura/luke-japanese-base-marcja'
model_name = 'line-corporation/japanese-large-lm-1.7b'
dataset_name, subset_name = 'shunk031/JGLUE', 'MARC-ja'
save_model_name = "rlhf-line-marcja-0828"

# %% [markdown]
# データセットを作成する関数を定義します。

# %%
def build_dataset(model_name, dataset_name, subset_name=None, split="train",
                  input_min_text_length=2, input_max_text_length=8):
    # トーカナイザをロード
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tokenizer.pad_token = tokenizer.eos_token

    # データセットをロード、長さが200以上のサンプルを残す
    ds = load_dataset(dataset_name, split=split, name=subset_name,
                      trust_remote_code=True)
    ds = ds.rename_columns({"sentence": "review"})
    ds = ds.filter(lambda x: len(x["review"]) > 200, batched=False)

    # 各サンプルの長さをランダムに選ぶ
    input_size = LengthSampler(input_min_text_length, input_max_text_length)

    # 入力サンプルに対して長さをランダムに選び、トークン列に変換
    def tokenize(sample):
        sample["input_ids"] = \
            tokenizer.encode(sample["review"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
# データセットを取得し、RLHFの対象となるモデルのトーカナイザでトークン列に変換
dataset = build_dataset(model_name, dataset_name, subset_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:473: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Downloading data: 0.00B [00:00, ?B/s]
# Downloading data:   0%|          | 0.00/3.09k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.42k [00:00<?, ?B/s]
# /root/.cache/huggingface/modules/datasets_modules/datasets/shunk031--JGLUE/bef660b0971cf102c95d2554bd2552ce5fb1cf8e9223cc6f8001c70be571c18c/JGLUE.py:464: UserWarning: can't import `mojimoji`, failing back to method that do nothing. We recommend running `pip install mojimoji` to reproduce the original preprocessing.
#   warnings.warn(
# WARNING:datasets_modules.datasets.shunk031--JGLUE.bef660b0971cf102c95d2554bd2552ce5fb1cf8e9223cc6f8001c70be571c18c.JGLUE:"None of [Index(['review_body', 'star_rating', 'review_id'], dtype='object')] are in the [columns]"
# Downloading data:   0%|          | 0.00/65.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Filter:   0%|          | 0/187528 [00:00<?, ? examples/s]
# Map:   0%|          | 0/71819 [00:00<?, ? examples/s]

# %%
len(dataset)
# Out:
# 71819

# %%
dataset[0]
# Out:
# {'review': '以前職場の方にこれをみて少しでも元氣になってくださいと手渡して、早３年。返してくれと一度言ったが、結局返ってこなかった。６年前にも、職場の（といっても海外ですが）英語の先生に貸したら、これは素晴らしい！と言って、授業でも何度も生徒に見せたり、家でも見てたりしたそうで、結局帰国までに返してもらえなかった。。。この作品、結局３回購入してます。とほほでありつつ、誰かの心の支えになってくれればと願いつつ。エンディングの曲も好きです。あー、自分も突き進む人生を歩みたい。結婚もしたいが。。。',
#  'label': tensor(0),
#  'review_id': 'R2H83XHJUDZBHT',
#  'input_ids': tensor([4964, 3752, 4488, 2833, 2474, 4481,  665]),
#  'query': '以前職場の方にこれをみて少しでも元'}

# %% [markdown]
# ### (5) 事前学習済みモデルの読み込み
# Hugging Face Hub上の事前学習済みモデルを読み込みます。

# %%
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)

model = AutoModelForCausalLMWithValueHead.from_pretrained(
    model_name,
    peft_config=lora_config,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.01k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# model.safetensors:   0%|          | 0.00/3.51G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/layer.py:1091: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/3.51G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/trl/models/modeling_base.py:326: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = loading_func(filename if not use_safe else safe_filename, **load_kwargs)
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:473: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %% [markdown]
# ### (6) 報酬モデルの読み込み
# 報酬モデルを読み込みます。

# %%
device = 0
sentiment_pipe = pipeline("sentiment-analysis", model=rm_name, device=device)
# Out:
# config.json:   0%|          | 0.00/937 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.88k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/842k [00:00<?, ?B/s]
# entity_vocab.json:   0%|          | 0.00/21.7M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/595 [00:00<?, ?B/s]

# %% [markdown]
# 動作を確認します。

# %%
sentiment_pipe("これは美味しくない", return_all_scores=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'LABEL_0', 'score': 0.028055215254426003},
#   {'label': 'LABEL_1', 'score': 0.9719448089599609}]]

# %% [markdown]
# ## ファインチューニング実装

# %% [markdown]
# ### (1) 学習条件の設定
# 学習条件の設定を`PPOTrainer`のコンストラクタに渡してインスタンス化します。

# %%
def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])

config = config = PPOConfig(
    model_name,
    learning_rate=1.41e-5,
    log_with="wandb",
)
ppo_trainer = PPOTrainer(config, model, tokenizer=tokenizer,
                         dataset=dataset, data_collator=collator)
# Out:
# Finishing last run (ID:7nymfq16) before initializing another...
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">dainty-sun-34</strong> at: <a href='https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized/runs/7nymfq16' target="_blank">https://wandb.ai/taku-yoshioka-laboro-ai/uncategorized/runs/7nymfq16</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240830_093645-7nymfq16/logs</code>
# Successfully finished last run (ID:7nymfq16). Initializing new run:<br/>
# wandb version 0.17.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/content/wandb/run-20240830_094817-xu59zxsf</code>
# Syncing run <strong><a href='https://wandb.ai/taku-yoshioka-laboro-ai/trl/runs/xu59zxsf' target="_blank">super-sunset-34</a></strong> to <a href='https://wandb.ai/taku-yoshioka-laboro-ai/trl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/taku-yoshioka-laboro-ai/trl' target="_blank">https://wandb.ai/taku-yoshioka-laboro-ai/trl</a>
#  View run at <a href='https://wandb.ai/taku-yoshioka-laboro-ai/trl/runs/xu59zxsf' target="_blank">https://wandb.ai/taku-yoshioka-laboro-ai/trl/runs/xu59zxsf</a>

# %% [markdown]
# ### (2) ファインチューニングの実行
#
# 以下のコードでファインチューニングを実行します。バッチサイズ256、A100 GPUで11時間程度かかります。

# %%
# 感情分析パイプラインのパラメータ
sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16}

# 生成文の長さをランダムに選択
output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)

# 文書生成パイプラインのパラメータ
generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}

for step, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    # # 動作確認用
    # if step >= 2:
    #     break

    query_tensors = batch["input_ids"]

    # 文書生成
    response_tensors = []
    for query in query_tensors:
        gen_len = output_length_sampler()
        generation_kwargs["max_new_tokens"] = gen_len
        response = ppo_trainer.generate(query, **generation_kwargs)
        response_tensors.append(response.squeeze()[-gen_len:])
    batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]

    # 報酬（感情スコア）の計算
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)

    assert pipe_outputs[0][0]["label"] == "LABEL_0"
    rewards = [torch.tensor(output[0]["score"]) for output in pipe_outputs]

    # PPO訓練ステップ
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# 8it [18:00, 135.37s/it]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# 13it [29:19, 135.75s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 14it [31:33, 135.21s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (51.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (42.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 20it [45:04, 135.25s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (27.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (19.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (18.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 27it [1:00:50, 135.05s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (99.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (98.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (97.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 65it [2:26:42, 135.56s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (64.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (65.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (66.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 66it [2:28:56, 135.21s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (176.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (177.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (175.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 68it [2:33:25, 134.60s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (77.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (81.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (85.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 74it [2:46:50, 133.80s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (242.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (253.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (240.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 76it [2:51:18, 134.15s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 79it [2:58:10, 136.13s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 86it [3:13:56, 135.02s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 87it [3:16:11, 135.10s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 94it [3:31:53, 134.83s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (55.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (48.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (49.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (40.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (43.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (54.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 104it [3:54:31, 136.29s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 112it [4:12:46, 137.19s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (38.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (38.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 116it [4:21:42, 134.69s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (13.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 123it [4:37:26, 135.19s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (15.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 128it [4:48:36, 134.12s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (40.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (38.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 133it [4:59:54, 136.05s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (12.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 135it [5:04:22, 135.23s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 143it [5:22:24, 135.51s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (37.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (35.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (35.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 146it [5:29:08, 134.96s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (21.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 147it [5:31:24, 135.23s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (563.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (174.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (61.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 154it [5:47:04, 133.78s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (16.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (14.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 157it [5:53:48, 134.04s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (898.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1058.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (1059.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 158it [5:56:03, 134.48s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (46.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (224.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (216.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (166.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 168it [6:18:31, 135.15s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (37.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (36.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (37.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 171it [6:25:17, 135.24s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (24.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 172it [6:27:32, 135.19s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (28.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (22.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 181it [6:47:39, 134.06s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 188it [7:03:24, 134.61s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (153756.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (40441904.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (642566389760.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 201it [7:32:21, 134.55s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (167.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (175.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (154.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 209it [7:50:10, 134.05s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (344533.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (308148.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (310238.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (83885.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 220it [8:14:37, 133.20s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (95.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (96.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (99.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 223it [8:21:17, 133.40s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (274.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 229it [8:34:34, 132.85s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (59.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (54.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (48.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 239it [8:56:53, 133.90s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 247it [9:14:44, 134.41s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 251it [9:23:44, 134.90s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (10.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 254it [9:30:26, 134.43s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (11.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 257it [9:37:08, 134.17s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (17.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 259it [9:41:38, 134.55s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (23.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (20.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 268it [10:01:44, 133.97s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (805.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (806.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1212: UserWarning: The average ratio of batch (806.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 280it [10:28:34, 134.69s/it]

# %% [markdown]
# ### モデルの保存

# %% [markdown]
# ファインチューニング済みのモデルを保存します。

# %%
ppo_trainer.save_pretrained(save_model_name, push_to_hub=True)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/14.2M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/taku-yoshioka/rlhf-line-marcja-0828/commit/bd3919d2877ca6bb04c5e01c0867994298e21c22', commit_message='Push model using huggingface_hub.', commit_description='', oid='bd3919d2877ca6bb04c5e01c0867994298e21c22', pr_url=None, pr_revision=None, pr_num=None)
